# %% [markdown]
# ![Screenshot%20%2897%29.png](attachment:Screenshot%20%2897%29.png)

# %% [markdown]
# <b>GRIP @ The Sparks Foundation - Data Science and Business Analytics

# %% [markdown]
# <b>TASK 4 : EXPLORATORY DATA ANALYSIS - TERRORISM

# %% [markdown]
# <b>Author : ALEENA VADAKKEDATHU SHAJAN

# %% [markdown]
# <B>Objective : To perform 'Exploratory Data Analysis' on the dataset 'Global Terrorism'.
#
#     ● As a security/defense analyst, try to find out the hot zone of terrorism.
#     ● What all security issues and insights you can derive by EDA?

# %% [markdown]
# <b>IMPORTING THE REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
os.chdir(r'C:\Users\ALEENA\Downloads')

# %% [markdown]
# <b>LOADING AND READING THE DATASET

# %%
df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding='latin1')
df.head(10)
# Out:
# C:\Users\ALEENA\OneDrive\Documents\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# ...

# %%
#renaming the columns
df.rename(columns={'iyear':'Year','imonth':'Month','extended':'Extended','iday':'Day','country_txt':'Country','provstate':'State',
                  'region_txt':'Region','attacktype1_txt':'Attacktype','target1':'Target','nkill':'Killed','nwound':'Wounded',
                   'summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive',
                  'city':'City','latitude':'Latitude','longitude':'Longitude'},inplace=True)
df.head(10)
# Out:
#         eventid  Year  Month  Day approxdate  Extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
# 5  197001010002  1970      1    1        NaN         0        NaN      217
# 6  197001020001  1970      1    2        NaN         0        NaN      218
# 7  197001020002  1970      1    2        NaN         0        NaN      217
# 8  197001020003  1970      1    2        NaN         0        NaN      217
# 9  197001030001  1970      1    3        NaN         0        NaN      217
#
#               Country  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
#keeping the necessary columns and removing the rest unnecessary ones
df=df[['Year','Month','Extended','Day','Country','State','Region','City','Latitude','Longitude','Attacktype',
       'Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]
df.head(10)
# Out:
#    Year  Month  Extended  Day             Country       State  \
# 0  1970      7         0    2  Dominican Republic         NaN
# 1  1970      0         0    0              Mexico     Federal
# 2  1970      1         0    0         Philippines      Tarlac
# 3  1970      1         0    0              Greece      Attica
# 4  1970      1         0    0               Japan     Fukouka
# 5  1970      1         0    1       United States    Illinois
# 6  1970      1         0    2             Uruguay  Montevideo
# 7  1970      1         0    2       United States  California
# 8  1970      1         0    2       United States   Wisconsin
# 9  1970      1         0    3       United States   Wisconsin
#
#                         Region           City   Latitude   Longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# ...

# %% [markdown]
# <b>FEATURE EXPLORATION

# %%
df.shape
# Out:
# (181691, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Extended     181691 non-null  int64
#  3   Day          181691 non-null  int64
#  4   Country      181691 non-null  object
#  5   State        181270 non-null  object
#  6   Region       181691 non-null  object
#  7   City         181257 non-null  object
#  8   Latitude     177135 non-null  float64
#  9   Longitude    177134 non-null  float64
#  10  Attacktype   181691 non-null  object
#  11  Killed       171378 non-null  float64
#  12  Wounded      165380 non-null  float64
#  13  Target       181055 non-null  object
#  14  Summary      115562 non-null  object
#  15  Group        181691 non-null  object
#  16  Target_type  181691 non-null  object
#  17  Weapon_type  181691 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Year          Month       Extended            Day  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277       0.045346      15.505644
# std        13.259430       3.388303       0.208063       8.814045
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       0.000000       8.000000
# 50%      2009.000000       6.000000       0.000000      15.000000
# 75%      2014.000000       9.000000       0.000000      23.000000
# max      2017.000000      12.000000       1.000000      31.000000
#
#             Latitude     Longitude         Killed        Wounded
# count  177135.000000  1.771340e+05  171378.000000  165380.000000
# mean       23.498343 -4.586957e+02       2.403272       3.167668
# std        18.569242  2.047790e+05      11.545741      35.949392
# min       -53.154613 -8.618590e+07       0.000000       0.000000
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Extended', 'Day', 'Country', 'State', 'Region',
#        'City', 'Latitude', 'Longitude', 'Attacktype', 'Killed', 'Wounded',
#        'Target', 'Summary', 'Group', 'Target_type', 'Weapon_type', 'Motive'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Year               47
# Month              13
# Extended            2
# Day                32
# Country           205
# State            2855
# Region             12
# City            36674
# Latitude        48322
# Longitude       48039
# Attacktype          9
# Killed            205
# Wounded           238
# Target          86006
# Summary        112492
# Group            3537
# Target_type        22
# Weapon_type        12
# Motive          14490
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Extended            0
# Day                 0
# Country             0
# State             421
# Region              0
# City              434
# Latitude         4556
# Longitude        4557
# Attacktype          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %% [markdown]
# <b>PLOTTING A HEATMAP

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# <b>DATA VISUALIZATION

# %% [markdown]
# <b>Countries with most terrorist attack

# %%
print("Country with the most attacks;\n",df['Country'].value_counts())
# Out:
# Country with the most attacks;
#  Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# North Korea                1
# Andorra                    1
# International              1
# Antigua and Barbuda        1
# Falkland Islands           1
# Name: Country, Length: 205, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['Country'].value_counts()[:15].index,df['Country'].value_counts()[:15].values)
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ALEENA\OneDrive\Documents\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <b>States with most terrorist attack

# %%
print('State with the most attacks:\n',df['State'].value_counts())
# Out:
# State with the most attacks:
#  Baghdad                              7645
# Northern Ireland                     4498
# Unknown                              4290
# Balochistan                          3710
# Saladin                              3411
#                                      ...
# Gwelo                                   1
# Mitidja Plains (Province)               1
# Guatemala City (Capital District)       1
# Sumatra (Province)                      1
# Maliana (District)                      1
# Name: State, Length: 2855, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['State'].value_counts()[:15].index,df['State'].value_counts()[:15].values)
plt.title('Top States Affected')
plt.xlabel('States')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ALEENA\OneDrive\Documents\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <b>Regions with most terrorist attack

# %%
print('Region with the most attacks:\n',df['Region'].value_counts())
# Out:
# Region with the most attacks:
#  Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['Region'].value_counts()[:15].index,df['Region'].value_counts()[:15].values)
plt.title('Top regions Affected')
plt.xlabel('Regions')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ALEENA\OneDrive\Documents\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <b>Cities with most terrorist attack

# %%
print('Cities with the most attacks:\n',df['City'].value_counts())
# Out:
# Cities with the most attacks:
#  Unknown          9775
# Baghdad          7589
# Karachi          2652
# Lima             2359
# Mosul            2265
#                  ...
# Feid-el-Botma       1
# Hiangtam            1
# Firyanah            1
# Al-Sharara          1
# Phola Park          1
# Name: City, Length: 36674, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['City'].value_counts()[:15].index,df['City'].value_counts()[:15].values)
plt.title('Top Cities Affected')
plt.xlabel('Cities')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ALEENA\OneDrive\Documents\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <b>Years with most terrorist attack

# %%
print('Year with the most attacks:\n',df['Year'].value_counts().head(10))
# Out:
# Year with the most attacks:
#  2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['Year'].value_counts()[:15].index,df['Year'].value_counts()[:15].values)
plt.title('Year with most terrorist attacks')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ALEENA\OneDrive\Documents\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <b>Most frequent Attack Types

# %%
print('Most frequent Attack Types:\n',df['Attacktype'].value_counts())
# Out:
# Most frequent Attack Types:
#  Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attacktype, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['Attacktype'].value_counts()[:15].index,df['Attacktype'].value_counts()[:15].values)
plt.title('Most frequent Attack Type')
plt.xlabel('Attack Type')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ALEENA\OneDrive\Documents\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <b>Most frequent Groups involved in past terrorist activities

# %%
print('Groups with the most attacks:\n',df['Group'].value_counts())
# Out:
# Groups with the most attacks:
#  Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
#                                                     ...
# Tribal Clash                                            1
# Mahaz-e-Milli Islami Afghanistan                        1
# Comando Autónomo Voltaire Argandoña                     1
# Armed Womens Nuclei                                     1
# Armed Brigades                                          1
# Name: Group, Length: 3537, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['Group'].value_counts()[:15].index,df['Group'].value_counts()[:15].values)
plt.title('Groups with most terrorist activities')
plt.xlabel('Group')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ALEENA\OneDrive\Documents\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <b>Most popularly used Weapon Type

# %%
print('Most popular Weapon Type:\n',df['Weapon_type'].value_counts())
# Out:
# Most popular Weapon Type:
#  Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['Weapon_type'].value_counts()[:15].index,df['Weapon_type'].value_counts()[:15].values)
plt.title('Most popular Weapon Type')
plt.xlabel('Weapon Type')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ALEENA\OneDrive\Documents\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <b>Killed Vs Wounded Visualization

# %%
df.plot(kind='scatter',x='Killed',y='Wounded',alpha=0.5,color='black',figsize=(10,5))
plt.title('Killed Vs Wounded')
plt.xlabel('Killed')
plt.ylabel('Wounded')
plt.show()

# %% [markdown]
# <b>CONCLUSION

# %% [markdown]
# <B>

# %% [markdown]
# **HOT ZONES**
#
#      1.In Country wise terrorist attack :-
#         a)Iraq : high rate
#         b)Spain : low rate
#
#      2.In State wise terrorist attack :-
#         a)Baghdad had the highest rate whereas,
#         b)Antioquia had the least
#
#      3.For Region wise terrorist attack :-
#         a)Middle East and North Africa was at the first position.
#         b)Australiasia and Oceania was at the last position.
#
#      4.Among the most frequently attacked cities :-
#         a)Baghdad was highly affected since the first one is unknown.
#
#      5.For year wise terrorist attack
#         a)2014 was the year most frequent terrorist attack in the past and,
#         b)1988 was with year with least attacks.

# %% [markdown]
# **INSIGHTS DRAWN**
#
#      1)The most frequent attack type was Bombing/Explosion.
#      2)The groups involved in terrorist activity were Talibans since the fist type of groups were unknown to people.
#      3)The most commonly used weapon for terrorist activity were Explosives.
# So from these above statement we can conclude that,it was wise for the people to stay at homes and avoid gatherings at crowded places or areas.

# %% [markdown]
# **FOR KILLED Vs WOUNDED VISUALIZATION PLOT,**
#
#      1)The census shows that most of the people who were killed and wounded lies under the range (300,1000).
#      2)The highest number of people killed and wounded due to the terrorist activity was 1400 and 8000 respectively.

# %% [markdown]
# **FROM THIS PROJECT BASED ON THE OBSERVATIONS I CAN FINALLY CONCLUDE THAT EVEN THOUGH THERE IS A PERCEPTION THAT MUSLIMS ARE THE SUPPORTERS OF TERRORISM,WE CAN CLEARLY SEE THAT MUSLIMS WERE THE ONES WHO WERE HIGHLY DAMAGED WITH INJURIES AND DEATH RATES BY THE IMPACT OF TERRORIST ATTACK.**
#
# **ON HAVING A KEEN OBSERVATION FOR THE COUNTRY WISE TERRORIST ATTACK GRAPHICS,IT APPEARS TO BE STATED THAT *IRAQ,AFGHANISTAN AND PAKISTAN* WERE THE MOST DAMAGED COUNTRIES.ALL THESE COUNTRIES WERE MUSLIM COUNTRIES AND THEY WERE THE ONES WHO WERE BADLY AFFECTED ON HAVING A COMPARISON WITH REST COUNTRIES.**
